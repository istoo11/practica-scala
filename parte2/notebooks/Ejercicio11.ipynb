// %%
val nombres = "Ana" :: "Luis" :: "Marta" :: Nil
val otrosNombres = List("Pedro","Sofia")

val listaUnida = nombres ::: otrosNombres
// Out:
// nombres: List[String] = List("Ana", "Luis", "Marta")
// otrosNombres: List[String] = List("Pedro", "Sofia")
// listaUnida: List[String] = List("Ana", "Luis", "Marta", "Pedro", "Sofia")
