// %% [markdown]
// # Scala Ejercicio 07
//
// ### Explicación
//
// Los valores de dentro del array aunque este este declarado como val, actuan como var
//
// El dato 500 no se puede introducir ya que no se pueden mezclar los datos ya que en el array solo hay datos de tipo String.
//
// ASignar la variable

// %%
val jugadores = Array("Alex", "Chen", "Marta")
println(jugadores)

jugadores(0) = "Sindhu"
println(jugadores)

jugadores(3) = 300
// Out:
// cmd1.sc:7: type mismatch;
//  found   : Int(300)
//  required: String
// val res1_4 = jugadores(3) = 300
//                             ^
// Compilation Failed
