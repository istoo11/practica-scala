// %% [markdown]
// # Scala Ejercicio 01
//
// ## Variables
//
// En Scala podemos declarar los datos o podemos dejar a Scala que infiera el tipo
//
// ### Observación
//
// En porcentajeVictorias al dejar que Scala infiera el tipo 60 lo ha detectado como Int

// %%
val nombreJugador: String = "Jugador1"
var numPartidas: Int = 10
var puntuacion: Int = 67
var porcentajeVictorias: Double = 60
var esActivo: Boolean = true
// Out:
// nombreJugador: String = "Jugador1"
// numPartidas: Int = 10
// puntuacion: Int = 67
// porcentajeVictorias: Double = 60.0
// esActivo: Boolean = true

// %%
val nombreJugador = "Jugador1"
var numPartidas = 10
var puntuacion = 67
var porcentajeVictorias = 60
var esActivo = true
// Out:
// nombreJugador: String = "Jugador1"
// numPartidas: Int = 10
// puntuacion: Int = 67
// porcentajeVictorias: Int = 60
// esActivo: Boolean = true
