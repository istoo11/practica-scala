// %% [markdown]
// # Scala Ejercicio 08
//
// ### Explicación
//
// El array inicialmente esta inicializado con cuatro **0**

// %%
val jugadores = new Array[Int](4)
jugadores.foreach(println)

jugadores(0) = 17
jugadores(1) = 24
jugadores(2) = 21
jugadores(3) = 19
jugadores.foreach(println)
println(jugadores.lenght)
// Out:
// 0
// 0
// 0
// 0
// 17
// 24
// 21
// 19
// jugadores: Array[Int] = Array(17, 24, 21, 19)
