// %%
def bust(puntuacion: Int): Boolean = {
    puntuacion>21
}

bust(18)
bust(21)
bust(22)
bust(30)
// Out:
// defined function bust
// res9_1: Boolean = false
// res9_2: Boolean = false
// res9_3: Boolean = true
// res9_4: Boolean = true
